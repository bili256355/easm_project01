# %% [markdown]
# # easm_project01 quickstart
#
# 这个 notebook 只演示如何从新包入口直接运行 preprocess + indices。

# %%
from pathlib import Path
import sys

project_root = Path(r'D:\\easm_project01')
src_root = project_root / 'src'
if str(src_root) not in sys.path:
    sys.path.insert(0, str(src_root))

from easm_project01.pipeline_runner import run_easm_project01
result = run_easm_project01()
result
